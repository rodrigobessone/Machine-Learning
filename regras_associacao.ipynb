# %% [markdown]
# # **APRENDIZAGEM NÃO SUPERVISIONADA: ASSOCIAÇÃO**

# %% [markdown]
# # **ECLAT**

# %%
# !pip install pyECLAT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyECLAT
#   Downloading pyECLAT-1.0.2-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.8/dist-packages (from pyECLAT) (1.3.5)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.8/dist-packages (from pyECLAT) (4.64.1)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.8/dist-packages (from pyECLAT) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25.3->pyECLAT) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25.3->pyECLAT) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->pyECLAT) (1.15.0)
# Installing collected packages: pyECLAT
# Successfully installed pyECLAT-1.0.2

# %%
from pyECLAT import Example1

# %%
dados = Example1().get()

# %%
dados
# Out:
#         0      1       2       3
# 0    milk   beer   bread  butter
# 1   coffe  bread  butter     NaN
# 2   coffe  bread  butter     NaN
# 3    milk  coffe   bread  butter
# 4    beer    NaN     NaN     NaN
# 5  butter    NaN     NaN     NaN
# 6   bread    NaN     NaN     NaN
# 7    bean    NaN     NaN     NaN
# 8    rice   bean     NaN     NaN
# 9    rice    NaN     NaN     NaN

# %%
from pyECLAT import ECLAT
eclat = ECLAT(data=dados, verbose=True)
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 334.22it/s]
# 100%|██████████| 7/7 [00:00<00:00, 47127.01it/s]
# 100%|██████████| 7/7 [00:00<00:00, 1315.95it/s]

# %%
eclat.df_bin
# Out:
#    coffe  beer  bean  bread  milk  rice  butter
# 0      0     1     0      1     1     0       1
# 1      1     0     0      1     0     0       1
# 2      1     0     0      1     0     0       1
# 3      1     0     0      1     1     0       1
# 4      0     1     0      0     0     0       0
# 5      0     0     0      0     0     0       1
# 6      0     0     0      1     0     0       0
# 7      0     0     1      0     0     0       0
# 8      0     0     1      0     0     1       0
# 9      0     0     0      0     0     1       0

# %%
eclat.uniq_
# Out:
# [nan, 'coffe', 'beer', 'bean', 'bread', 'milk', 'rice', 'butter']

# %%
indices, suporte = eclat.fit(min_support=0.2, min_combination=2, max_combination=4)
# Out:
# Combination 2 by 2
# 21it [00:00, 132.60it/s]
# Combination 3 by 3
# 35it [00:00, 165.37it/s]
# Combination 4 by 4
# 35it [00:00, 225.00it/s]

# %%
indices
# Out:
# {'coffe & bread': [1, 2, 3],
#  'coffe & butter': [1, 2, 3],
#  'bread & milk': [0, 3],
#  'bread & butter': [0, 1, 2, 3],
#  'milk & butter': [0, 3],
#  'coffe & bread & butter': [1, 2, 3],
#  'bread & milk & butter': [0, 3]}

# %%
suporte
# Out:
# {'coffe & bread': 0.3,
#  'coffe & butter': 0.3,
#  'bread & milk': 0.2,
#  'bread & butter': 0.4,
#  'milk & butter': 0.2,
#  'coffe & bread & butter': 0.3,
#  'bread & milk & butter': 0.2}

# %% [markdown]
# # **APRIORI**

# %%
from pyECLAT import Example1
dados = Example1().get()
dados
# Out:
#         0      1       2       3
# 0    milk   beer   bread  butter
# 1   coffe  bread  butter     NaN
# 2   coffe  bread  butter     NaN
# 3    milk  coffe   bread  butter
# 4    beer    NaN     NaN     NaN
# 5  butter    NaN     NaN     NaN
# 6   bread    NaN     NaN     NaN
# 7    bean    NaN     NaN     NaN
# 8    rice   bean     NaN     NaN
# 9    rice    NaN     NaN     NaN

# %%
dados.shape
# Out:
# (10, 4)

# %%
from pyECLAT import ECLAT
eclat = ECLAT(data=dados)
dados2 = eclat.df_bin
dados2
# Out:
#    coffe  beer  bean  bread  milk  rice  butter
# 0      0     1     0      1     1     0       1
# 1      1     0     0      1     0     0       1
# 2      1     0     0      1     0     0       1
# 3      1     0     0      1     1     0       1
# 4      0     1     0      0     0     0       0
# 5      0     0     0      0     0     0       1
# 6      0     0     0      1     0     0       0
# 7      0     0     1      0     0     0       0
# 8      0     0     1      0     0     1       0
# 9      0     0     0      0     0     1       0

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Gerando a associação
associacao = apriori(dados2, min_support=0.05, use_colnames=True)

# %%
# Colocando em ordem dos mais frequentes
associacao.sort_values("support", ascending=False).head(15)
# Out:
#     support                      itemsets
# 6       0.5                      (butter)
# 3       0.5                       (bread)
# 15      0.4               (bread, butter)
# 0       0.3                       (coffe)
# 7       0.3                (coffe, bread)
# 9       0.3               (coffe, butter)
# 18      0.3        (coffe, bread, butter)
# 5       0.2                        (rice)
# 4       0.2                        (milk)
# 23      0.2         (milk, bread, butter)
# 1       0.2                        (beer)
# 14      0.2                 (milk, bread)
# 2       0.2                        (bean)
# 16      0.2                (milk, butter)
# 24      0.1  (milk, coffe, bread, butter)

# %%
# Criando as regras de associação
regras = association_rules(associacao, metric="confidence")

# %%
# Colocando em ordem de suporte, confiança ou grau de associação (Lift)
resultado = regras.sort_values("lift", ascending=False)

# %%
resultado.head(30)
# Out:
#               antecedents      consequents  antecedent support  \
# 28         (beer, butter)    (bread, milk)                 0.1
# 16         (beer, butter)           (milk)                 0.1
# 27          (beer, bread)   (milk, butter)                 0.1
# 25  (beer, bread, butter)           (milk)                 0.1
# 12          (beer, bread)           (milk)                 0.1
# 26           (beer, milk)  (bread, butter)                 0.1
# 22          (coffe, milk)  (bread, butter)                 0.1
# 9                 (coffe)  (bread, butter)                 0.3
# 19                 (milk)  (bread, butter)                 0.2
# 24   (beer, milk, butter)          (bread)                 0.1
# 23    (bread, beer, milk)         (butter)                 0.1
# 21  (coffe, milk, butter)          (bread)                 0.1
# 20   (bread, coffe, milk)         (butter)                 0.1
# 18         (milk, butter)          (bread)                 0.2
# 17          (bread, milk)         (butter)                 0.2
# 0                 (coffe)          (bread)                 0.3
# 15           (beer, milk)         (butter)                 0.1
# 1                 (coffe)         (butter)                 0.3
# 13          (beer, bread)         (butter)                 0.1
# 11           (beer, milk)          (bread)                 0.1
# 10          (coffe, milk)         (butter)                 0.1
# 8         (coffe, butter)          (bread)                 0.3
# 7          (coffe, bread)         (butter)                 0.3
# 6           (coffe, milk)          (bread)                 0.1
# 5                  (milk)         (butter)                 0.2
# 2                  (milk)          (bread)                 0.2
# 14         (beer, butter)          (bread)                 0.1
# 4                (butter)          (bread)                 0.5
# 3                 (bread)         (butter)                 0.5
#
#     consequent support  support  confidence  lift  leverage  conviction
# 28                 0.2      0.1         1.0   5.0      0.08         inf
# 16                 0.2      0.1         1.0   5.0      0.08         inf
# 27                 0.2      0.1         1.0   5.0      0.08         inf
# 25                 0.2      0.1         1.0   5.0      0.08         inf
# 12                 0.2      0.1         1.0   5.0      0.08         inf
# 26                 0.4      0.1         1.0   2.5      0.06         inf
# 22                 0.4      0.1         1.0   2.5      0.06         inf
# 9                  0.4      0.3         1.0   2.5      0.18         inf
# 19                 0.4      0.2         1.0   2.5      0.12         inf
# 24                 0.5      0.1         1.0   2.0      0.05         inf
# 23                 0.5      0.1         1.0   2.0      0.05         inf
# 21                 0.5      0.1         1.0   2.0      0.05         inf
# 20                 0.5      0.1         1.0   2.0      0.05         inf
# 18                 0.5      0.2         1.0   2.0      0.10         inf
# 17                 0.5      0.2         1.0   2.0      0.10         inf
# 0                  0.5      0.3         1.0   2.0      0.15         inf
# 15                 0.5      0.1         1.0   2.0      0.05         inf
# 1                  0.5      0.3         1.0   2.0      0.15         inf
# 13                 0.5      0.1         1.0   2.0      0.05         inf
# 11                 0.5      0.1         1.0   2.0      0.05         inf
# 10                 0.5      0.1         1.0   2.0      0.05         inf
# 8                  0.5      0.3         1.0   2.0      0.15         inf
# 7                  0.5      0.3         1.0   2.0      0.15         inf
# 6                  0.5      0.1         1.0   2.0      0.05         inf
# 5                  0.5      0.2         1.0   2.0      0.10         inf
# 2                  0.5      0.2         1.0   2.0      0.10         inf
# 14                 0.5      0.1         1.0   2.0      0.05         inf
# 4                  0.5      0.4         0.8   1.6      0.15         2.5
# 3                  0.5      0.4         0.8   1.6      0.15         2.5
